# %%
import numpy as np
import pandas as pd

import requests
from bs4 import BeautifulSoup

# %% [markdown]
# # Web Scrapping

# %% [markdown]
# 1. requests - This is used to extract the HTML code from the given URL
# 2. BeautifulSoup - Format and Scrap the data from the HTML
#
# Steps:
#
# 1. Identify URL
# 2. Inspect HTML code
# 3. Find the HTML tag for the element that you want to extract
# 4. Write code to scrap data

# %%
# Identify the URL
URL = 'https://www.flipkart.com/laptops/~cs-g5q3mw47a4/pr?sid=6bo%2Cb5g&collection-tab-name=Browsing&wid=12.productCard.PMU_V2_5'

# %%
# Loading the webpage in Memory using requests library
web_page = requests.get(URL)

# %%
#Check the status code of the page

web_page.status_code
# Out:
# 200

# %%
# Extract the HTML code of the WebPage
html_code = web_page.text

# %%
html_code
# Out:
# '<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.7f97aa.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/><link rel="apple-touch-icon" sizes="72x72" href="/apple-touch-icon-72x72.png"/><link rel="appl
# ...

# %% [markdown]
# Price -  div class = _30jeq3 _1_WHN1
#
# Product - div class = _4rR01T
#
# rating - div class = _3LWZlK
#
# features - ul class = _1xgFaf

# %%
soup = BeautifulSoup(html_code)

# %%
help(soup)
# Out:
# Help on BeautifulSoup in module bs4 object:
#
# class BeautifulSoup(bs4.element.Tag)
#  |  BeautifulSoup(markup='', features=None, builder=None, parse_only=None, from_encoding=None, exclude_encodings=None, element_classes=None, **kwargs)
#  |
#  |  A data structure representing a parsed HTML or XML document.
#  |
#  |  Most of the methods you'll call on a BeautifulSoup object are inherited from
#  |  PageElement or Tag.
#  |
#  |  Internally, this class defines the basic interface called by the
#  |  tree builders when converting an HTML/XML document into a data
#  |  structure. The interface abstracts away the differences between
#  |  parsers. To write a new tree builder, you'll need to understand
#  |  these methods as a whole.
#  |
#  |  These methods will be called by the BeautifulSoup constructor:
#  |    * reset()
#  |    * feed(markup)
#  |
#  |  The tree builder may call these methods from its feed() implementation:
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim1.flixcart.com" rel="preconnect"/>
#   <link href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.7f97aa.css" rel="stylesheet"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <meta content="noodp" name="robots"/>
#   <link href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
#   <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Flipkart.com" name="og_site_name" property="og:site_name"/>
#   <link href="/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# ...

# %%
# price

price = soup.find('div', attrs = {'class' : '_30jeq3 _1_WHN1'})
print(price)
print(type(price))
print(price.text)
# Out:
# <div class="_30jeq3 _1_WHN1">₹25,990</div>
# <class 'bs4.element.Tag'>
# ₹25,990

# %%
# title

title = soup.find('div', attrs = {'class' : '_4rR01T' })

print(title.text)
# Out:
# Lenovo V Series Athlon Dual Core 3150U - (4 GB/1 TB HDD/Windows 10 Home) V-15 ADA Laptop

# %%
# rating

rating = soup.find('div', attrs = {'class' : '_3LWZlK' })

print(rating.text)
# Out:
# 4.1

# %%
# feature

feature = soup.find('ul', attrs = { 'class' : '_1xgFaf' })

print(feature.text)
# Out:
# AMD Athlon Dual Core Processor4 GB DDR4 RAM64 bit Windows 10 Operating System1 TB HDD39.62 cm (15.6 Inch) DisplayMicrosoft Office (Trial Only)1 Year Onsite Warranty

# %%
# price all

price_all = soup.find_all('div', attrs = {'class' : '_30jeq3 _1_WHN1'})

print(type(price_all))

print(price_all)

print(type(price_all[1]))

for tag in price_all:
    print(tag.text)
# Out:
# <class 'bs4.element.ResultSet'>
# ...

# %%
# title all

title_all = soup.find_all('div', attrs = {'class' : '_4rR01T' })

for tag in title_all:
    print(tag.text)
# Out:
# Lenovo V Series Athlon Dual Core 3150U - (4 GB/1 TB HDD/Windows 10 Home) V-15 ADA Laptop
# DELL Vostro Core i3 10th Gen - (4 GB/256 GB SSD/Windows 10 Home) Vostro 3401 Thin and Light Laptop
# HP 15s Core i3 10th Gen - (8 GB/1 TB HDD/Windows 10 Home) 15s-DU1066TU Thin and Light Laptop
# acer Extensa 15 Pentium Quad Core - (4 GB/256 GB SSD/Windows 10 Home) EX215-31 Laptop
# ASUS VivoBook 15 Core i3 10th Gen - (8 GB/1 TB HDD/Windows 10 Home) X515JA-EJ322TS Thin and Light Lapt...
# HP 15s Ryzen 3 Dual Core 3250U - (4 GB/1 TB HDD/Windows 10 Home) 15s-GR0006AU Thin and Light Laptop
# HP 15s Core i3 11th Gen - (8 GB/1 TB HDD/Windows 10 Home) 15s-du3038TU Thin and Light Laptop
# DELL Vostro Core i3 10th Gen - (8 GB/1 TB HDD/Windows 10 Home) Vostro 3401 Thin and Light Laptop
# ASUS Chromebooks Celeron Dual Core - (4 GB/64 GB EMMC Storage/Chrome OS) C423NA-BZ0522 Thin and Light ...
# Lenovo IdeaPad Core i3 10th Gen - (8 GB/256 GB SSD/Windows 10 Home) 14 IML 05 Thin and Light Laptop
# ...

# %%
# rating all

rating_all = soup.find_all('div', attrs = {'class' : '_3LWZlK' })

for tag in rating_all:
    print(tag.text)
# Out:
# 4.1
# 4.3
# 4.4
# 4.2
# 4.1
# 3.9
# 4.1
# 4
# 4.5
# 3.8
# 3.9
# 4.2
# 3.8
# 3.9
# 4.5
# 3.8
# 3.8
# 4.3
# 4.3
# 3.8
# 4
# 3.8
# 4
# 4
# 5
# 3
# 4.3
# 3
# 4
# 3.8
# 5
# 5
# 4.4
# 4
# 5
# 3.8
# 4
# 1

# %% [markdown]
# # Let's look into all the URL's
#
# https://www.flipkart.com/laptops/~cs-g5q3mw47a4/pr?sid=6bo%2Cb5g&collection-tab-name=Browsing&wid=12.productCard.PMU_V2_5&page=1
#
# https://www.flipkart.com/laptops/~cs-g5q3mw47a4/pr?sid=6bo%2Cb5g&collection-tab-name=Browsing&wid=12.productCard.PMU_V2_5&page=2

# %%
#code

for i in range(1,3):
    print('https://www.flipkart.com/laptops/~cs-g5q3mw47a4/pr?sid=6bo%2Cb5g&collection-tab-name=Browsing&wid=12.productCard.PMU_V2_5&page={}'.format(i))
# Out:
# https://www.flipkart.com/laptops/~cs-g5q3mw47a4/pr?sid=6bo%2Cb5g&collection-tab-name=Browsing&wid=12.productCard.PMU_V2_5&page=1
# https://www.flipkart.com/laptops/~cs-g5q3mw47a4/pr?sid=6bo%2Cb5g&collection-tab-name=Browsing&wid=12.productCard.PMU_V2_5&page=2

# %% [markdown]
# # Code for scrapping (Incorrect way)

# %%
# %%time

title = []
rating = []
price = []
feature = []

for i in range(1,3):
    URL = 'https://www.flipkart.com/laptops/~cs-g5q3mw47a4/pr?sid=6bo%2Cb5g&collection-tab-name=Browsing&wid=12.productCard.PMU_V2_5&page={}'.format(i)
    
    web_page = requests.get(URL)  # load webpage in the memory
    html_code = web_page.text     # extract the HTML code 
     
    soup = BeautifulSoup(html_code) # convert HTML code to soup
    
    title_all = soup.find_all('div', attrs = {'class' : '_4rR01T' })
    for item in title_all:
        title.append(item.text)
        
    rating_all = soup.find_all('div', attrs = {'class' : '_3LWZlK' })
    for item in rating_all:
        rating.append(item.text)
        
    price_all = soup.find_all('div', attrs = {'class' : '_30jeq3 _1_WHN1' })
    for item in price_all:
        price.append(item.text)
        
    feature_all = soup.find_all('ul', attrs = {'class' : '_1xgFaf' })
    for item in feature_all:
        feature.append(item.text)
# Out:
# CPU times: user 219 ms, sys: 13.6 ms, total: 233 ms
# Wall time: 1.63 s

# %%
print(len(title))
print(len(rating))
print(len(price))
print(len(feature))
# Out:
# 27
# 50
# 27
# 27

# %% [markdown]
# # Code for web scrapping (correct way)

# %%
# %%time

title = []
rating = []
price = []
feature = []

for i in range(1,3):
    URL = 'https://www.flipkart.com/laptops/~cs-g5q3mw47a4/pr?sid=6bo%2Cb5g&collection-tab-name=Browsing&wid=12.productCard.PMU_V2_5&page={}'.format(i)
    
    web_page = requests.get(URL)  # load webpage in the memory
    html_code = web_page.text     # extract the HTML code 
     
    soup = BeautifulSoup(html_code) # convert HTML code to soup
    
    for x in soup.find_all('div', attrs = {'class' : '_2kHMtA' }):
    
        product = x.find('div', attrs = {'class' : '_4rR01T' })
        if product is None:
            title.append(np.NaN)
        else:
            title.append(product.text)

        rate = x.find('div', attrs = {'class' : '_3LWZlK' })
        if rate is None:
            rating.append(np.NaN)
        else:
            rating.append(rate.text)

        mrp = x.find('div', attrs = {'class' : '_30jeq3 _1_WHN1' })
        if mrp is None:
            price.append(np.NaN)
        else:
            price.append(mrp.text)

        f = x.find('ul', attrs = {'class' : '_1xgFaf' })
        if f is None:
            feature.append(np.NaN)
        else:
            feature.append(f.text)
# Out:
# CPU times: user 262 ms, sys: 20.3 ms, total: 282 ms
# Wall time: 1.79 s

# %%
print(len(title))
print(len(rating))
print(len(price))
print(len(feature))
# Out:
# 27
# 27
# 27
# 27

# %% [markdown]
# # Create DataFrame and save it in CSV file

# %%
df = pd.DataFrame({'Product' : title, 'Rating' : rating, 'MRP' : price, 'Feature' : feature })

# %%
df
# Out:
#                                               Product Rating      MRP  \
# 0   Lenovo V Series Athlon Dual Core 3150U - (4 GB...    4.1  ₹32,250
# 1   DELL Vostro Core i3 10th Gen - (4 GB/256 GB SS...    4.3  ₹36,490
# 2   HP 15s Core i3 10th Gen - (8 GB/1 TB HDD/Windo...    4.4  ₹40,990
# 3   acer Extensa 15 Pentium Quad Core - (4 GB/256 ...    4.2  ₹26,490
# 4   ASUS VivoBook 15 Core i3 10th Gen - (8 GB/1 TB...    4.1  ₹39,990
# 5   HP 15s Ryzen 3 Dual Core 3250U - (4 GB/1 TB HD...    3.9  ₹32,490
# 6   HP 15s Core i3 11th Gen - (8 GB/1 TB HDD/Windo...    4.1  ₹42,490
# 7   DELL Vostro Core i3 10th Gen - (8 GB/1 TB HDD/...      4  ₹38,220
# 8   Lenovo IdeaPad Core i3 10th Gen - (8 GB/256 GB...    NaN  ₹39,990
# 9   Lenovo V Series Athlon Dual Core 3050U - (4 GB...    3.8  ₹27,990
# 10  ASUS Chromebooks Celeron Dual Core - (4 GB/64 ...    4.5  ₹23,999
# 11  DELL Inspiron Ryzen 3 Dual Core 3250U - (8 GB/...    3.9  ₹35,680
# ...

# %%
df.shape
# Out:
# (27, 4)

# %%
df.tail()
# Out:
#                                               Product Rating      MRP  \
# 22  ASUS VivoBook 15 Athlon Dual Core 3050U - (4 G...    3.8  ₹28,990
# 23  HP Chromebook MT8183 - (4 GB/64 GB EMMC Storag...      4  ₹22,990
# 24  ASUS Chromebooks Celeron Dual Core - (4 GB/32 ...    3.8  ₹17,999
# 25  HP 12b Celeron Dual Core - (4 GB/Chrome OS) 12...    3.8  ₹29,990
# 26  acer Celeron Dual Core 7th Gen - (4 GB/32 GB E...    3.5  ₹23,990
#
#                                               Feature
# 22  AMD Athlon Dual Core Processor4 GB DDR4 RAM64 ...
# 23  MediaTek MT8183 Processor4 GB DDR4 RAM32 bit C...
# 24  Intel Celeron Dual Core Processor4 GB LPDDR4X ...
# 25  Intel Celeron Dual Core Processor4 GB DDR4 RAM...
# 26  Intel Celeron Dual Core Processor (7th Gen)4 G...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Product  27 non-null     object
#  1   Rating   26 non-null     object
#  2   MRP      27 non-null     object
#  3   Feature  27 non-null     object
# dtypes: object(4)
# memory usage: 992.0+ bytes

# %%
df.to_csv('Laptop_Details.csv', index=False)

# %%
df.to_csv('temp.csv')

# %%
# !pwd
# Out:
# /Users/pranayvaddepalli/Desktop/Exercise files

# %% [markdown]
# # Extract details using Regex

# %%
import numpy as np
import pandas as pd
import re

# %%
df = pd.read_csv('Laptop_Details.csv')
df.head()
# Out:
#                                              Product  Rating      MRP  \
# 0  Lenovo V Series Athlon Dual Core 3150U - (4 GB...     4.1  ₹32,250
# 1  DELL Vostro Core i3 10th Gen - (4 GB/256 GB SS...     4.3  ₹36,490
# 2  HP 15s Core i3 10th Gen - (8 GB/1 TB HDD/Windo...     4.4  ₹40,990
# 3  acer Extensa 15 Pentium Quad Core - (4 GB/256 ...     4.2  ₹26,490
# 4  ASUS VivoBook 15 Core i3 10th Gen - (8 GB/1 TB...     4.1  ₹39,990
#
#                                              Feature
# 0  AMD Athlon Dual Core Processor4 GB DDR4 RAM64 ...
# 1  Intel Core i3 Processor (10th Gen)4 GB DDR4 RA...
# 2  Intel Core i3 Processor (10th Gen)8 GB DDR4 RA...
# 3  Intel Pentium Quad Core Processor4 GB DDR4 RAM...
# 4  Intel Core i3 Processor (10th Gen)8 GB DDR4 RA...

# %%
print(df['Feature'][0])
print(df.Feature[2])
print(df.Feature[6])
# Out:
# AMD Athlon Dual Core Processor4 GB DDR4 RAM64 bit Windows 10 Operating System1 TB HDD39.62 cm (15.6 Inch) DisplayMicrosoft Office (Trial Only)1 Year Onsite Warranty
# Intel Core i3 Processor (10th Gen)8 GB DDR4 RAM64 bit Windows 10 Operating System1 TB HDD39.62 cm (15.6 Inch) DisplayMicrosoft Office Home and Student 2019, McAfee LiveSafe (30 Day Free Trial), HP Documentation, HP BIOS Recovery, HP Smart1 Year Onsite Warranty
# Intel Core i3 Processor (11th Gen)8 GB DDR4 RAM64 bit Windows 10 Operating System1 TB HDD39.62 cm (15.6 inch) DisplayHP Documentation, HP BIOS Recovery, HP Smart, Dropbox, HP Support Assistant, Microsoft Office Home and Student 20191 Year Onsite Warranty

# %%
def square(x):
    return x ** 2

# %%
print(square(5))
# Out:
# 25

# %%
# lambda is used in the place of defination.
# it is annomyous function
sq = lambda x: x ** 2
print(sq(4))
# Out:
# 16

# %%
# Processor Information

regex = r'^(?:AMD|Intel|M1)[\s\w]+Processor'

df['Processor'] = df['Feature'].apply(lambda x: re.findall(regex,x))

# %%
df.head()
# Out:
#                                              Product  Rating      MRP  \
# 0  Lenovo V Series Athlon Dual Core 3150U - (4 GB...     4.1  ₹32,250
# 1  DELL Vostro Core i3 10th Gen - (4 GB/256 GB SS...     4.3  ₹36,490
# 2  HP 15s Core i3 10th Gen - (8 GB/1 TB HDD/Windo...     4.4  ₹40,990
# 3  acer Extensa 15 Pentium Quad Core - (4 GB/256 ...     4.2  ₹26,490
# 4  ASUS VivoBook 15 Core i3 10th Gen - (8 GB/1 TB...     4.1  ₹39,990
#
#                                              Feature  \
# 0  AMD Athlon Dual Core Processor4 GB DDR4 RAM64 ...
# 1  Intel Core i3 Processor (10th Gen)4 GB DDR4 RA...
# 2  Intel Core i3 Processor (10th Gen)8 GB DDR4 RA...
# 3  Intel Pentium Quad Core Processor4 GB DDR4 RAM...
# 4  Intel Core i3 Processor (10th Gen)8 GB DDR4 RA...
#
#                              Processor
# 0     [AMD Athlon Dual Core Processor]
# 1            [Intel Core i3 Processor]
# 2            [Intel Core i3 Processor]
# 3  [Intel Pentium Quad Core Processor]
# ...

# %%
#RAM

regex = r'\d+\sGB[\s\w]+RAM'

df['RAM'] = df['Feature'].apply(lambda x: re.findall(regex, x))

# %%
df.head()
# Out:
#                                              Product  Rating      MRP  \
# 0  Lenovo V Series Athlon Dual Core 3150U - (4 GB...     4.1  ₹32,250
# 1  DELL Vostro Core i3 10th Gen - (4 GB/256 GB SS...     4.3  ₹36,490
# 2  HP 15s Core i3 10th Gen - (8 GB/1 TB HDD/Windo...     4.4  ₹40,990
# 3  acer Extensa 15 Pentium Quad Core - (4 GB/256 ...     4.2  ₹26,490
# 4  ASUS VivoBook 15 Core i3 10th Gen - (8 GB/1 TB...     4.1  ₹39,990
#
#                                              Feature  \
# 0  AMD Athlon Dual Core Processor4 GB DDR4 RAM64 ...
# 1  Intel Core i3 Processor (10th Gen)4 GB DDR4 RA...
# 2  Intel Core i3 Processor (10th Gen)8 GB DDR4 RA...
# 3  Intel Pentium Quad Core Processor4 GB DDR4 RAM...
# 4  Intel Core i3 Processor (10th Gen)8 GB DDR4 RA...
#
#                              Processor              RAM
# 0     [AMD Athlon Dual Core Processor]  [4 GB DDR4 RAM]
# 1            [Intel Core i3 Processor]  [4 GB DDR4 RAM]
# ...

# %%
#OS

regex = r'[\d]+[\s]bit[\s\w]+Operating System'

df['OS'] = df['Feature'].apply(lambda x : re.findall(regex,x))

# %%
df.head()
# Out:
#                                              Product  Rating      MRP  \
# 0  Lenovo V Series Athlon Dual Core 3150U - (4 GB...     4.1  ₹32,250
# 1  DELL Vostro Core i3 10th Gen - (4 GB/256 GB SS...     4.3  ₹36,490
# 2  HP 15s Core i3 10th Gen - (8 GB/1 TB HDD/Windo...     4.4  ₹40,990
# 3  acer Extensa 15 Pentium Quad Core - (4 GB/256 ...     4.2  ₹26,490
# 4  ASUS VivoBook 15 Core i3 10th Gen - (8 GB/1 TB...     4.1  ₹39,990
#
#                                              Feature  \
# 0  AMD Athlon Dual Core Processor4 GB DDR4 RAM64 ...
# 1  Intel Core i3 Processor (10th Gen)4 GB DDR4 RA...
# 2  Intel Core i3 Processor (10th Gen)8 GB DDR4 RA...
# 3  Intel Pentium Quad Core Processor4 GB DDR4 RAM...
# 4  Intel Core i3 Processor (10th Gen)8 GB DDR4 RA...
#
#                              Processor              RAM  \
# 0     [AMD Athlon Dual Core Processor]  [4 GB DDR4 RAM]
# 1            [Intel Core i3 Processor]  [4 GB DDR4 RAM]
# ...

# %%
#STORAGE

regex = r'[\d]+\s(?:GB|TB)\s(?:HDD|SSD)'

df['STORAGE'] = df['Feature'].apply(lambda x : re.findall(regex,x))

# %%
df.head()
# Out:
#                                              Product  Rating      MRP  \
# 0  Lenovo V Series Athlon Dual Core 3150U - (4 GB...     4.1  ₹32,250
# 1  DELL Vostro Core i3 10th Gen - (4 GB/256 GB SS...     4.3  ₹36,490
# 2  HP 15s Core i3 10th Gen - (8 GB/1 TB HDD/Windo...     4.4  ₹40,990
# 3  acer Extensa 15 Pentium Quad Core - (4 GB/256 ...     4.2  ₹26,490
# 4  ASUS VivoBook 15 Core i3 10th Gen - (8 GB/1 TB...     4.1  ₹39,990
#
#                                              Feature  \
# 0  AMD Athlon Dual Core Processor4 GB DDR4 RAM64 ...
# 1  Intel Core i3 Processor (10th Gen)4 GB DDR4 RA...
# 2  Intel Core i3 Processor (10th Gen)8 GB DDR4 RA...
# 3  Intel Pentium Quad Core Processor4 GB DDR4 RAM...
# 4  Intel Core i3 Processor (10th Gen)8 GB DDR4 RA...
#
#                              Processor              RAM  \
# 0     [AMD Athlon Dual Core Processor]  [4 GB DDR4 RAM]
# 1            [Intel Core i3 Processor]  [4 GB DDR4 RAM]
# ...

# %%
#Brand

regex = r'^\w+'

df['Brand'] = df['Product'].apply(lambda x : re.findall(regex, x))

# %%
df.head()
# Out:
#                                              Product  Rating      MRP  \
# 0  Lenovo V Series Athlon Dual Core 3150U - (4 GB...     4.1  ₹32,250
# 1  DELL Vostro Core i3 10th Gen - (4 GB/256 GB SS...     4.3  ₹36,490
# 2  HP 15s Core i3 10th Gen - (8 GB/1 TB HDD/Windo...     4.4  ₹40,990
# 3  acer Extensa 15 Pentium Quad Core - (4 GB/256 ...     4.2  ₹26,490
# 4  ASUS VivoBook 15 Core i3 10th Gen - (8 GB/1 TB...     4.1  ₹39,990
#
#                                              Feature  \
# 0  AMD Athlon Dual Core Processor4 GB DDR4 RAM64 ...
# 1  Intel Core i3 Processor (10th Gen)4 GB DDR4 RA...
# 2  Intel Core i3 Processor (10th Gen)8 GB DDR4 RA...
# 3  Intel Pentium Quad Core Processor4 GB DDR4 RAM...
# 4  Intel Core i3 Processor (10th Gen)8 GB DDR4 RA...
#
#                              Processor              RAM  \
# 0     [AMD Athlon Dual Core Processor]  [4 GB DDR4 RAM]
# 1            [Intel Core i3 Processor]  [4 GB DDR4 RAM]
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Product    27 non-null     object
#  1   Rating     26 non-null     float64
#  2   MRP        27 non-null     object
#  3   Feature    27 non-null     object
#  4   Processor  27 non-null     object
#  5   RAM        27 non-null     object
#  6   OS         27 non-null     object
#  7   STORAGE    27 non-null     object
#  8   Brand      27 non-null     object
# dtypes: float64(1), object(8)
# memory usage: 2.0+ KB

# %%
#Missing Values - in which columns how many missing values are present

df.isnull().sum()
# Out:
# Product      0
# Rating       1
# MRP          0
# Feature      0
# Processor    0
# RAM          0
# OS           0
# STORAGE      0
# Brand        0
# dtype: int64

# %%
print(df.Processor[0])
print(type(df['Processor'][0]))
# Out:
# ['AMD Athlon Dual Core Processor']
# <class 'list'>

# %%
print(''.join(df.Processor[0]))
print(type(''.join(df.Processor[0])))
# Out:
# AMD Athlon Dual Core Processor
# <class 'str'>

# %%
df.Processor = df.Processor.apply(lambda x : ''.join(x))
df.RAM = df.RAM.apply(lambda x : ''.join(x))
df.OS = df.OS.apply(lambda x : ''.join(x))
df.STORAGE = df.STORAGE.apply(lambda x : ''.join(x))
df.Brand = df.Brand.apply(lambda x : ''.join(x))

# %%
df.head()
# Out:
#                                              Product  Rating      MRP  \
# 0  Lenovo V Series Athlon Dual Core 3150U - (4 GB...     4.1  ₹32,250
# 1  DELL Vostro Core i3 10th Gen - (4 GB/256 GB SS...     4.3  ₹36,490
# 2  HP 15s Core i3 10th Gen - (8 GB/1 TB HDD/Windo...     4.4  ₹40,990
# 3  acer Extensa 15 Pentium Quad Core - (4 GB/256 ...     4.2  ₹26,490
# 4  ASUS VivoBook 15 Core i3 10th Gen - (8 GB/1 TB...     4.1  ₹39,990
#
#                                              Feature  \
# 0  AMD Athlon Dual Core Processor4 GB DDR4 RAM64 ...
# 1  Intel Core i3 Processor (10th Gen)4 GB DDR4 RA...
# 2  Intel Core i3 Processor (10th Gen)8 GB DDR4 RA...
# 3  Intel Pentium Quad Core Processor4 GB DDR4 RAM...
# 4  Intel Core i3 Processor (10th Gen)8 GB DDR4 RA...
#
#                            Processor            RAM  \
# 0     AMD Athlon Dual Core Processor  4 GB DDR4 RAM
# 1            Intel Core i3 Processor  4 GB DDR4 RAM
# 2            Intel Core i3 Processor  8 GB DDR4 RAM
# ...

# %%
df.MRP = df.MRP.apply(lambda x : x.replace('₹', '').replace(',', '')).astype(float)

# %%
df.head()
# Out:
#                                              Product  Rating      MRP  \
# 0  Lenovo V Series Athlon Dual Core 3150U - (4 GB...     4.1  32250.0
# 1  DELL Vostro Core i3 10th Gen - (4 GB/256 GB SS...     4.3  36490.0
# 2  HP 15s Core i3 10th Gen - (8 GB/1 TB HDD/Windo...     4.4  40990.0
# 3  acer Extensa 15 Pentium Quad Core - (4 GB/256 ...     4.2  26490.0
# 4  ASUS VivoBook 15 Core i3 10th Gen - (8 GB/1 TB...     4.1  39990.0
#
#                                              Feature  \
# 0  AMD Athlon Dual Core Processor4 GB DDR4 RAM64 ...
# 1  Intel Core i3 Processor (10th Gen)4 GB DDR4 RA...
# 2  Intel Core i3 Processor (10th Gen)8 GB DDR4 RA...
# 3  Intel Pentium Quad Core Processor4 GB DDR4 RAM...
# 4  Intel Core i3 Processor (10th Gen)8 GB DDR4 RA...
#
#                            Processor            RAM  \
# 0     AMD Athlon Dual Core Processor  4 GB DDR4 RAM
# 1            Intel Core i3 Processor  4 GB DDR4 RAM
# 2            Intel Core i3 Processor  8 GB DDR4 RAM
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Product    27 non-null     object
#  1   Rating     26 non-null     float64
#  2   MRP        27 non-null     float64
#  3   Feature    27 non-null     object
#  4   Processor  27 non-null     object
#  5   RAM        27 non-null     object
#  6   OS         27 non-null     object
#  7   STORAGE    27 non-null     object
#  8   Brand      27 non-null     object
# dtypes: float64(2), object(7)
# memory usage: 2.0+ KB

# %% [markdown]
# # Data Viz

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.head()
# Out:
#                                              Product  Rating      MRP  \
# 0  Lenovo V Series Athlon Dual Core 3150U - (4 GB...     4.1  32250.0
# 1  DELL Vostro Core i3 10th Gen - (4 GB/256 GB SS...     4.3  36490.0
# 2  HP 15s Core i3 10th Gen - (8 GB/1 TB HDD/Windo...     4.4  40990.0
# 3  acer Extensa 15 Pentium Quad Core - (4 GB/256 ...     4.2  26490.0
# 4  ASUS VivoBook 15 Core i3 10th Gen - (8 GB/1 TB...     4.1  39990.0
#
#                                              Feature  \
# 0  AMD Athlon Dual Core Processor4 GB DDR4 RAM64 ...
# 1  Intel Core i3 Processor (10th Gen)4 GB DDR4 RA...
# 2  Intel Core i3 Processor (10th Gen)8 GB DDR4 RA...
# 3  Intel Pentium Quad Core Processor4 GB DDR4 RAM...
# 4  Intel Core i3 Processor (10th Gen)8 GB DDR4 RA...
#
#                            Processor            RAM  \
# 0     AMD Athlon Dual Core Processor  4 GB DDR4 RAM
# 1            Intel Core i3 Processor  4 GB DDR4 RAM
# 2            Intel Core i3 Processor  8 GB DDR4 RAM
# ...

# %%
plt.figure(figsize=(15,7))
sns.boxplot(x = df.Brand, y = df.MRP)
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='MRP'>

# %%
plt.figure(figsize=(15,7))
g = sns.displot(df.MRP, kind='kde')
g.set_xticklabels(rotation=45)

# %%
plt.figure(figsize=(15,7))
sns.countplot(df.Brand)
# Out:
# /Applications/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Brand', ylabel='count'>

# %% [markdown]
# Observation : The above plot shows that count for each product. We can see that ASUS is having highest no. of products listed on Flipkart website

# %%
plt.figure(figsize=(15,7))
plt.xticks(rotation='vertical')
sns.distplot(df.MRP)
# Out:
# /Applications/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='MRP', ylabel='Density'>

# %%
df.groupby(['Brand']).agg({'MRP' : ['min', 'max', 'mean']})
# Out:
#             MRP
#             min      max          mean
# Brand
# ASUS    17999.0  39990.0  25662.666667
# DELL    35680.0  39650.0  37510.000000
# HP      22990.0  42490.0  31418.571429
# Lenovo  25997.0  39990.0  31556.750000
# acer    23990.0  42990.0  31156.666667

# %%
plt.figure(figsize=(15,7))
df.groupby(['Brand'])['MRP'].max().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Brand'>

# %%
plt.figure(figsize=(15,7))
df.groupby(['Brand'])['MRP'].min().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Brand'>

# %%
plt.figure(figsize=(15,7))
df.groupby(['Brand'])['MRP'].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Brand'>
